# %%
import pandas as pd
df = pd.read_excel('interview_db.xlsx')

# %%
df
# Out:
#        Unnamed: 0   FormID               AdSoyad          Telefon  Durum  \
# 0               0  1016995         Ghada Mansour   00962788826966  iptal
# 1               1  1017017                 ayman    0096264799000  iptal
# 2               2  1017260              Abdullah  009647502314584  iptal
# 3               3  1017268                ayoosh   00971557080430  iptal
# 4               4  1017269                  Awat   00207701302840  iptal
# ...           ...      ...                   ...              ...    ...
# 32450       32450  1005498                 الغزي  009647800086057  iptal
# 32451       32451  1005597                 Ahmad   00962788616485  iptal
# 32452       32452  1005625  تامر عبد الغفور احمد    0096555494226  iptal
# 32453       32453  1005684                 مايرا   00962793365278  iptal
# 32454       32454  1005758         Turkiya Mofth   00971529076665  iptal
#
#               Satisci  OdenenTutar  UtmSource               UtmContent  \
# ...
